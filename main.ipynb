# %%
from appliance import Appliance
from dataset_loader import get_file_names, load_data, create_appliance_objects
from display import plot_power, suggest_reduction
from data_analyzer import DataAnalyzer

data_files = get_file_names()   # get the list of files in the /data directory

appliance_dict = create_appliance_objects(data_files)   # get a dictionary with all of the appliances

data_analyzer = DataAnalyzer()   # instantiate all the data analyzer

for key in appliance_dict:
    data_analyzer.add_appliance(appliance_dict[key])    # go through and add all of the appliance objects to the DataAnalyzer class

total_time_dict = data_analyzer.get_total_time()
rms_power_dict = data_analyzer.get_rms_power()
energy_cost_dict = data_analyzer.get_energy_cost()
# Out:
# {'3D_printer': <appliance.Appliance object at 0x000002A305667380>, 'air_conditioner': <appliance.Appliance object at 0x000002A3056F2490>, 'air_purifier': <appliance.Appliance object at 0x000002A3056F2710>, 'boiler': <appliance.Appliance object at 0x000002A3057450F0>, 'coffee_maker': <appliance.Appliance object at 0x000002A305745350>, 'computer': <appliance.Appliance object at 0x000002A305774830>, 'dehumidifier': <appliance.Appliance object at 0x000002A3056C7240>, 'dishwasher': <appliance.Appliance object at 0x000002A3056C7350>, 'dryer': <appliance.Appliance object at 0x000002A30576D750>, 'fan': <appliance.Appliance object at 0x000002A30576D950>, 'freezer': <appliance.Appliance object at 0x000002A3056EA8A0>, 'fridge': <appliance.Appliance object at 0x000002A3056EAA80>, 'internet_router': <appliance.Appliance object at 0x000002A305784670>, 'laptop_1': <appliance.Appliance object at 0x000002A305784590>, 'laptop_2': <appliance.Appliance object at 0x000002A3057C5300>, 'monitor': <appliance.Appliance object at 0x000002A305721310>, 'phone_charger': <appliance.Appliance object at 0x000002A305721490>, 'printer': <appliance.Appliance object at 0x000002A3057C0100>, 'radiator': <appliance.Appliance object at 0x000002A3057C09F0>, 'sound_system': <appliance.Appliance object at 0x000002A3057A0870>, 'tv': <appliance.Appliance object at 0x000002A3057A0B90>, 'vacuum': <appliance.Appliance object at 0x000002A30570D130>, 'washing_machine': <appliance.Appliance object at 0x000002A3057AF450>}

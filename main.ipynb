# %%
from appliance import Appliance
from dataset_loader import get_file_names, load_data, create_appliance_objects
from display import plot_power, suggest_reduction
from data_analyzer import DataAnalyzer

data_files = get_file_names()   # get the list of files in the /data directory

appliance_dict = create_appliance_objects(data_files)   # get a dictionary with all of the appliances

data_analyzer = DataAnalyzer()   # instantiate all the data analyzer

for key in appliance_dict:
    DataAnalyzer.add_appliance(appliance_dict[key])    # go through and add all of the appliance objects to the DataAnalyzer class

total_time_dict = DataAnalyzer.get_total_time()
rms_power_dict = DataAnalyzer.get_rms_power()
energy_cost_dict = DataAnalyzer.get_energy_costs()

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from appliance import Appliance
#       2 from dataset_loader import get_file_names, load_data, create_appliance_objects
#       3 from display import plot_power, suggest_reduction
#
# ModuleNotFoundError: No module named 'appliance'
